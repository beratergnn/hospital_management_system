-- %% [markdown]
-- # [DBHospitalAutomatisation]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DBHospitalAutomatisation]    Script Date: 25.05.2023 20:45:59 ******/
CREATE DATABASE [DBHospitalAutomatisation]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DBHospitalAutomatisation', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\DBHospitalAutomatisation.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DBHospitalAutomatisation_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\DBHospitalAutomatisation_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [DBHospitalAutomatisation] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DBHospitalAutomatisation].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ARITHABORT OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET  ENABLE_BROKER 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET  MULTI_USER 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DBHospitalAutomatisation] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DBHospitalAutomatisation] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [DBHospitalAutomatisation] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[TBLAPPOINTMENT]

-- %%
USE [DBHospitalAutomatisation]
GO

-- %%
/****** Object:  Table [dbo].[TBLAPPOINTMENT]    Script Date: 25.05.2023 20:45:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBLAPPOINTMENT](
	[appointment_id] [int] IDENTITY(1,1) NOT NULL,
	[doctor_id_no] [char](11) NULL,
	[patient_id_no] [char](11) NULL,
	[policlinic_name] [varchar](50) NULL,
	[appointment_d_time] [smalldatetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[appointment_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBLDOCTOR]

-- %%
/****** Object:  Table [dbo].[TBLDOCTOR]    Script Date: 25.05.2023 20:45:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBLDOCTOR](
	[doctor_id_no] [char](11) NOT NULL,
	[doctor_name] [varchar](25) NULL,
	[doctor_surname] [varchar](25) NULL,
	[policlinic_name] [varchar](50) NULL,
	[doctor_phone_number] [char](11) NULL,
	[doctor_password] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[doctor_id_no] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBLPATIENT]

-- %%
/****** Object:  Table [dbo].[TBLPATIENT]    Script Date: 25.05.2023 20:45:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBLPATIENT](
	[patient_id_no] [char](11) NOT NULL,
	[patient_name] [varchar](25) NULL,
	[patient_surname] [varchar](25) NULL,
	[policlinic_name] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[patient_id_no] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBLPOLICLINIC]

-- %%
/****** Object:  Table [dbo].[TBLPOLICLINIC]    Script Date: 25.05.2023 20:45:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBLPOLICLINIC](
	[policlinic_name] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[policlinic_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBLRESULTS]

-- %%
/****** Object:  Table [dbo].[TBLRESULTS]    Script Date: 25.05.2023 20:45:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBLRESULTS](
	[result_id] [int] IDENTITY(1,1) NOT NULL,
	[result_text] [varchar](255) NULL,
	[patient_id] [char](11) NULL,
	[doctor_id] [char](11) NULL,
	[policlinic_name] [varchar](50) NULL,
	[appointment_id] [int] NULL,
	[result_d_time] [smalldatetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[result_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TBLSECRETARY]

-- %%
/****** Object:  Table [dbo].[TBLSECRETARY]    Script Date: 25.05.2023 20:45:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TBLSECRETARY](
	[secretary_id_no] [char](11) NOT NULL,
	[secretary_name] [varchar](25) NULL,
	[secretary_surname] [varchar](25) NULL,
	[secretary_password] [varchar](50) NULL,
	[secretary_phone_number] [varchar](11) NULL,
PRIMARY KEY CLUSTERED 
(
	[secretary_id_no] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__TBLAPPOIN__docto__3F466844]

-- %%
ALTER TABLE [dbo].[TBLAPPOINTMENT]  WITH CHECK ADD FOREIGN KEY([doctor_id_no])
REFERENCES [dbo].[TBLDOCTOR] ([doctor_id_no])
GO

-- %% [markdown]
-- # [FK__TBLAPPOIN__patie__403A8C7D]

-- %%
ALTER TABLE [dbo].[TBLAPPOINTMENT]  WITH CHECK ADD FOREIGN KEY([patient_id_no])
REFERENCES [dbo].[TBLPATIENT] ([patient_id_no])
GO

-- %% [markdown]
-- # [FK__TBLAPPOIN__polic__412EB0B6]

-- %%
ALTER TABLE [dbo].[TBLAPPOINTMENT]  WITH CHECK ADD FOREIGN KEY([policlinic_name])
REFERENCES [dbo].[TBLPOLICLINIC] ([policlinic_name])
GO

-- %% [markdown]
-- # [FK__TBLDOCTOR__polic__38996AB5]

-- %%
ALTER TABLE [dbo].[TBLDOCTOR]  WITH CHECK ADD FOREIGN KEY([policlinic_name])
REFERENCES [dbo].[TBLPOLICLINIC] ([policlinic_name])
GO

-- %% [markdown]
-- # [FK__TBLPATIEN__polic__48CFD27E]

-- %%
ALTER TABLE [dbo].[TBLPATIENT]  WITH CHECK ADD FOREIGN KEY([policlinic_name])
REFERENCES [dbo].[TBLPOLICLINIC] ([policlinic_name])
GO

-- %% [markdown]
-- # [FK__TBLRESULT__appoi__46E78A0C]

-- %%
ALTER TABLE [dbo].[TBLRESULTS]  WITH CHECK ADD FOREIGN KEY([appointment_id])
REFERENCES [dbo].[TBLAPPOINTMENT] ([appointment_id])
GO

-- %% [markdown]
-- # [FK__TBLRESULT__docto__44FF419A]

-- %%
ALTER TABLE [dbo].[TBLRESULTS]  WITH CHECK ADD FOREIGN KEY([doctor_id])
REFERENCES [dbo].[TBLDOCTOR] ([doctor_id_no])
GO

-- %% [markdown]
-- # [FK__TBLRESULT__patie__440B1D61]

-- %%
ALTER TABLE [dbo].[TBLRESULTS]  WITH CHECK ADD FOREIGN KEY([patient_id])
REFERENCES [dbo].[TBLPATIENT] ([patient_id_no])
GO

-- %% [markdown]
-- # [FK__TBLRESULT__polic__45F365D3]

-- %%
ALTER TABLE [dbo].[TBLRESULTS]  WITH CHECK ADD FOREIGN KEY([policlinic_name])
REFERENCES [dbo].[TBLPOLICLINIC] ([policlinic_name])
GO

-- %% [markdown]
-- # [DBHospitalAutomatisation]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DBHospitalAutomatisation] SET  READ_WRITE 
GO
